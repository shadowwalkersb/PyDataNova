# %%
import os
from sqlalchemy import create_engine, inspect
from pymongo import MongoClient
# from supabase import create_client
from dotenv import load_dotenv

load_dotenv(dotenv_path=os.path.join("../../.env"))

NEON_URL = os.getenv("NEON_URL")
MONGO_URL = os.getenv("MONGO_URL")

SUPABASE_URL = os.getenv("SUPABASE_URL")
SUPABASE_KEY = os.getenv("SUPABASE_KEY")

# %%
from supabase import create_client

# eng = create_client(SUPABASE_URL, SUPABASE_KEY)
eng = create_engine(SUPABASE_URL, echo=True)
inspector = inspect(eng)

# eng.schema.get_tables()
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File ~/miniforge3/envs/pydatanova-test/lib/python3.13/site-packages/sqlalchemy/engine/base.py:143, in Connection.__init__(self, engine, connection, _has_events, _allow_revalidate, _allow_autobegin)
#     142 try:
# --> 143     self._dbapi_connection = engine.raw_connection()
#     144 except dialect.loaded_dbapi.Error as err:
#
# File ~/miniforge3/envs/pydatanova-test/lib/python3.13/site-packages/sqlalchemy/engine/base.py:3301, in Engine.raw_connection(self)
#    3280 """Return a "raw" DBAPI connection from the connection pool.
#    3281
#    3282 The returned object is a proxied version of the DBAPI
#    (...)   3299
#    3300 """
# -> 3301 return self.pool.connect()
#
# File ~/miniforge3/envs/pydatanova-test/lib/python3.13/site-packages/sqlalchemy/pool/base.py:447, in Pool.connect(self)
# ...

# %%
client = MongoClient(MONGO_URL)
mongo_db = client.get_database("pydatanova_db")
mongo_db.list_collection_names()
# tbl = mongo_db.get_collection("users")
# client.admin.command("ping")
client.close()
# Out:
# ---------------------------------------------------------------------------
# OperationFailure                          Traceback (most recent call last)
# Cell In[35], line 3
#       1 client = MongoClient(MONGO_URL)
#       2 mongo_db = client.get_database("pydatanova_db")
# ----> 3 mongo_db.list_collection_names()
#       4 # tbl = mongo_db.get_collection("users")
#       5 # client.admin.command("ping")
#       6 client.close()
#
# File ~/miniforge3/envs/pydatanova-test/lib/python3.13/site-packages/pymongo/synchronous/database.py:1226, in Database.list_collection_names(self, session, filter, comment, **kwargs)
#    1194 def list_collection_names(
#    1195     self,
#    1196     session: Optional[ClientSession] = None,
#    (...)   1199     **kwargs: Any,
#    1200 ) -> list[str]:
#    1201     """Get a list of all the collection names in this database.
#    1202
#    1203     For example, to list all non-system collections::
#    (...)   1224     .. versionadded:: 3.6
# ...

# %%
engine = create_engine(NEON_URL, echo=1)

inspector = inspect(engine)

inspector.get_table_names()

# %%
# Out:
# 'postgresql'
